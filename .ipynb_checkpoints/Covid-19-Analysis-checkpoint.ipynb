# %% [markdown]
# # Covid-19 Data Analysis

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# Dataviz
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
corona_list = pd.io.html.read_html(url)

# %%
corona_dframe = corona_list[0]

# %%
corona_dframe
# Out:
#      Unnamed: 0 Province/State         Country/Region        Lat       Long  \
# 0           NaN            NaN            Afghanistan  33.939110  67.709953
# 1           NaN            NaN                Albania  41.153300  20.168300
# 2           NaN            NaN                Algeria  28.033900   1.659600
# 3           NaN            NaN                Andorra  42.506300   1.521800
# 4           NaN            NaN                 Angola -11.202700  17.873900
# ..          ...            ...                    ...        ...        ...
# 261         NaN            NaN  Sao Tome and Principe   0.186400   6.613100
# 262         NaN            NaN                  Yemen  15.552727  48.516388
# 263         NaN            NaN                Comoros -11.645500  43.333300
# 264         NaN            NaN             Tajikistan  38.861000  71.276100
# 265         NaN            NaN                Lesotho -29.610000  28.233600
#
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  ...  7/15/20  7/16/20  \
# 0          0        0        0        0        0  ...    34994    35070
# 1          0        0        0        0        0  ...     3752     3851
# 2          0        0        0        0        0  ...    20770    21355
# 3          0        0        0        0        0  ...      862      877
# 4          0        0        0        0        0  ...      576      607
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 261        0        0        0        0        0  ...      737      740
# 262        0        0        0        0        0  ...     1526     1552
# 263        0        0        0        0        0  ...      321      328
# 264        0        0        0        0        0  ...     6695     6741
# 265        0        0        0        0        0  ...      256      256
#
#      7/17/20  7/18/20  7/19/20  7/20/20  7/21/20  7/22/20  7/23/20  7/24/20
# 0      35229    35301    35475    35526    35615    35727    35928    35981
# 1       3906     4008     4090     4171     4290     4358     4466     4570
# 2      21948    22549    23084    23691    24278    24872    25484    26159
# 3        880      880      880      884      884      889      889      897
# 4        638      687      705      749      779      812      851      880
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 261      741      743      746      746      746      747      749      860
# 262     1576     1581     1606     1619     1629     1640     1654     1674
# 263      328      328      334      334      337      337      340      340
# 264     6786     6834     6878     6921     6967     7015     7060     7104
# 265      311      359      359      359      359      359      359      359
#
# [266 rows x 190 columns]

# %%
corona_dframe.drop(['Lat','Long'],axis=1,inplace=True)

# %%
corona_dframe.head()
# Out:
#    Unnamed: 0 Province/State Country/Region  1/22/20  1/23/20  1/24/20  \
# 0         NaN            NaN    Afghanistan        0        0        0
# 1         NaN            NaN        Albania        0        0        0
# 2         NaN            NaN        Algeria        0        0        0
# 3         NaN            NaN        Andorra        0        0        0
# 4         NaN            NaN         Angola        0        0        0
#
#    1/25/20  1/26/20  1/27/20  1/28/20  ...  7/15/20  7/16/20  7/17/20  \
# 0        0        0        0        0  ...    34994    35070    35229
# 1        0        0        0        0  ...     3752     3851     3906
# 2        0        0        0        0  ...    20770    21355    21948
# 3        0        0        0        0  ...      862      877      880
# 4        0        0        0        0  ...      576      607      638
#
#    7/18/20  7/19/20  7/20/20  7/21/20  7/22/20  7/23/20  7/24/20
# 0    35301    35475    35526    35615    35727    35928    35981
# 1     4008     4090     4171     4290     4358     4466     4570
# 2    22549    23084    23691    24278    24872    25484    26159
# 3      880      880      884      884      889      889      897
# 4      687      705      749      779      812      851      880
#
# [5 rows x 188 columns]

# %%
corona_dframe_agg = corona_dframe.groupby('Country/Region').sum()
corona_dframe_agg.head()
# Out:
#                 Unnamed: 0  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan            0.0        0        0        0        0        0
# Albania                0.0        0        0        0        0        0
# Algeria                0.0        0        0        0        0        0
# Andorra                0.0        0        0        0        0        0
# Angola                 0.0        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  7/15/20  7/16/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...    34994    35070
# Albania               0        0        0        0  ...     3752     3851
# Algeria               0        0        0        0  ...    20770    21355
# Andorra               0        0        0        0  ...      862      877
# Angola                0        0        0        0  ...      576      607
#
#                 7/17/20  7/18/20  7/19/20  7/20/20  7/21/20  7/22/20  7/23/20  \
# Country/Region
# Afghanistan       35229    35301    35475    35526    35615    35727    35928
# Albania            3906     4008     4090     4171     4290     4358     4466
# Algeria           21948    22549    23084    23691    24278    24872    25484
# Andorra             880      880      880      884      884      889      889
# Angola              638      687      705      749      779      812      851
#
#                 7/24/20
# Country/Region
# Afghanistan       35981
# Albania            4570
# Algeria           26159
# Andorra             897
# Angola              880
#
# [5 rows x 186 columns]

# %%
corona_dframe_agg.shape
# Out:
# (188, 186)

# %%
corona_dframe_agg.drop('Unnamed: 0',axis=1,inplace=True)

# %%
corona_dframe_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 188 entries, Afghanistan to Zimbabwe
# Columns: 185 entries, 1/22/20 to 7/24/20
# dtypes: int64(185)
# memory usage: 273.2+ KB

# %%
corona_dframe_agg.loc['US'].plot()
corona_dframe_agg.loc['Brazil'].plot()
corona_dframe_agg.loc['India'].plot()
plt.legend()
plt.title('Top 3 affected countries currently',weight='bold')
plt.xlabel('Dates')
plt.ylabel('No. of cases')
# Out:
# Text(0, 0.5, 'No. of cases')

# %%
corona_dframe_agg.loc['China'][:3].plot()

# %%
corona_dframe_agg.loc['US'].diff().plot()
corona_dframe_agg.loc['Brazil'].diff().plot()
corona_dframe_agg.loc['India'].diff().plot()
plt.legend()
plt.title('Top 3 affected countries currently',weight='bold')
plt.xlabel('Dates')
plt.ylabel('No. of cases')
# Out:
# Text(0, 0.5, 'No. of cases')

# %%
corona_dframe_agg.loc['US'].diff().max()
# Out:
# 77255.0

# %%
corona_dframe_agg.loc['Brazil'].diff().max()
# Out:
# 67860.0

# %%
corona_dframe_agg.loc['India'].diff().max()
# Out:
# 49310.0

# %%
countries = list(corona_dframe_agg.index)
max_infection_rates = [corona_dframe_agg.loc[c].diff().max() for c in countries]

# %%
corona_dframe_agg['Max Infection Rates'] = max_infection_rates

# %%
corona_dframe_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  7/16/20  7/17/20  7/18/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...    35070    35229    35301
# Albania               0        0        0  ...     3851     3906     4008
# Algeria               0        0        0  ...    21355    21948    22549
# Andorra               0        0        0  ...      877      880      880
# Angola                0        0        0  ...      607      638      687
#
#                 7/19/20  7/20/20  7/21/20  7/22/20  7/23/20  7/24/20  \
# Country/Region
# Afghanistan       35475    35526    35615    35727    35928    35981
# Albania            4090     4171     4290     4358     4466     4570
# Algeria           23084    23691    24278    24872    25484    26159
# Andorra             880      884      884      889      889      897
# Angola              705      749      779      812      851      880
#
#                 Max Infection Rates
# Country/Region
# Afghanistan                   915.0
# Albania                       119.0
# Algeria                       675.0
# Andorra                        79.0
# Angola                         62.0
#
# [5 rows x 186 columns]

# %%
cleaned_corona_dframe = DataFrame(corona_dframe_agg['Max Infection Rates'])
cleaned_corona_dframe.head()
# Out:
#                 Max Infection Rates
# Country/Region
# Afghanistan                   915.0
# Albania                       119.0
# Algeria                       675.0
# Andorra                        79.0
# Angola                         62.0

# %%
happiness_dframe = pd.read_csv('worldwide_happiness_report.csv')

# %%
happiness_dframe.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
drop_cols = ['Overall rank','Generosity','Score','Perceptions of corruption']

# %%
happiness_dframe.drop(drop_cols,axis=1,inplace=True)

# %%
happiness_dframe.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_dframe.set_index('Country or region',inplace=True)

# %%
happiness_dframe.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
cleaned_corona_dframe.shape
# Out:
# (188, 1)

# %%
happiness_dframe.shape
# Out:
# (156, 4)

# %%
countries_dframe = cleaned_corona_dframe.join(happiness_dframe,how='inner')

# %% [markdown]
# Here as number of countries in corona dataset were greater than those in happiness dataset so we use inner join, as inner join takes intersection of the two datasets

# %%
countries_dframe.head()
# Out:
#              Max Infection Rates  GDP per capita  Social support  \
# Afghanistan                915.0           0.350           0.517
# Albania                    119.0           0.947           0.848
# Algeria                    675.0           1.002           1.160
# Argentina                 6127.0           1.092           1.432
# Armenia                    771.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
corr_countries_dframe = countries_dframe.corr()

# %%
corr_countries_dframe
# Out:
#                               Max Infection Rates  GDP per capita  \
# Max Infection Rates                      1.000000        0.121044
# GDP per capita                           0.121044        1.000000
# Social support                           0.095748        0.757521
# Healthy life expectancy                  0.109350        0.859431
# Freedom to make life choices             0.069248        0.394799
#
#                               Social support  Healthy life expectancy  \
# Max Infection Rates                 0.095748                 0.109350
# GDP per capita                      0.757521                 0.859431
# Social support                      1.000000                 0.751632
# Healthy life expectancy             0.751632                 1.000000
# Freedom to make life choices        0.456317                 0.423146
#
#                               Freedom to make life choices
# Max Infection Rates                               0.069248
# GDP per capita                                    0.394799
# Social support                                    0.456317
# Healthy life expectancy                           0.423146
# Freedom to make life choices                      1.000000

# %%
x = countries_dframe['GDP per capita']
y = countries_dframe['Max Infection Rates']
y = np.log(y)

# %% [markdown]
# #### Max Infection Rates vs GDP per capita

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True, figsize=(10,5))
sns.scatterplot(x, y, ax=ax1)
sns.regplot(x, y, ax=ax2)

# %%
x = countries_dframe['Social support']

# %% [markdown]
# #### Max Infection Rates vs Social support

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True, figsize=(10,5))
sns.scatterplot(x, y, ax=ax1)
sns.regplot(x, y, ax=ax2)

# %%
x = countries_dframe['Healthy life expectancy']

# %% [markdown]
# #### Max Infection Rates vs Healthy life expectancy

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True, figsize=(10,5))
sns.scatterplot(x, y, ax=ax1)
sns.regplot(x, y, ax=ax2)

# %%
x = countries_dframe['Freedom to make life choices']

# %% [markdown]
# #### Max Infection Rates vs Freedom to make life choices

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True, figsize=(10,5))
sns.scatterplot(x, y, ax=ax1)
sns.regplot(x, y, ax=ax2)

# %% [markdown]
# Out of the all four factors Max Infection Rates is most strongly correlated to GDP per capita, even though the correlation is low but out of the four it is the most important factor.<br />
# A rather intresting find is that next follwed best correlation is against Healthy life expectancy, it felt kind of wierd to see that the countries with Healthy life expectancy are somewhat correlated to Max Infection Rates.<br />
# Whereas the least correlated factor was Freedom to make life choices.<br />
# Although all the correlations were less than 0.200000

# %%
sns.pairplot(happiness_dframe.dropna())

# %%
returns_fig = sns.PairGrid(happiness_dframe.dropna())

returns_fig.map_upper(plt.scatter,color='indianred')
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')
returns_fig.map_diag(plt.hist,bins=30,edgecolor='black')

# %% [markdown]
# Here we can see that Healthy life expectancy is strongly correlated with GDP per capita and Social Support.

# %% [markdown]
# # Done!
